# %%
import pandas as pd

# %%
data = pd.read_csv('Data/logistic_regression/logistic_regression-knn_PCA.csv', low_memory=False)
data
# Out:
#     Unnamed: 0  Peptide  Peptide_pred           0           1           2
# 0            2        0             0 -170.731633   -0.315470   18.858771  \
# 1           13        0             0   36.973518  210.044976   18.079442
# 2           53        1             1 -107.550240  -97.900863  -47.641916
# 3           41        1             1   15.627628  -60.947675 -111.095499
# 4           74        0             0  211.723093  133.719161  -23.798717
# 5           30        1             1   17.831393   91.488418  -99.787310
# 6           45        1             1  112.736540    3.178343   48.391039
# 7           43        1             1    0.921642 -103.416272    0.367580
# 8           57        1             1   33.348566   93.092117  -95.579571
# 9           85        0             0 -165.940628    6.209889   31.324255
# 10           7        0             0    8.660850  247.425760  -21.587326
# 11          26        1             1  130.970371  -24.075856  -88.495305
# ...

# %%
import matplotlib.pyplot as plt 
from sklearn.metrics import confusion_matrix
#
y_test = data['Peptide']
y_true = data['Peptide']
# Get the predictions
#
y_pred = data['Peptide_pred']
#
# Calculate the confusion matrix
#
conf_matrix = confusion_matrix(y_true=y_test, y_pred=y_pred)
#
# Print the confusion matrix using Matplotlib
#
fig, ax = plt.subplots(figsize=(7.5, 7.5))
ax.matshow(conf_matrix, cmap=plt.cm.Blues, alpha=0.3)
for i in range(conf_matrix.shape[0]):
    for j in range(conf_matrix.shape[1]):
        ax.text(x=j, y=i,s=conf_matrix[i, j], va='center', ha='center', size='xx-large')
 
plt.xlabel('Predictions', fontsize=18)
plt.ylabel('Actuals', fontsize=18)
plt.title('logistic_regression-knn_PCA', fontsize=18)
plt.show()

# %%
data = pd.read_csv('Data/logistic_regression/logistic_regression-mean_PCA.csv', low_memory=False)
data
# Out:
#     Unnamed: 0  Peptide  Peptide_pred           0           1           2
# 0            2        0             0  -99.844958   23.105279    2.505970  \
# 1           13        0             0   95.261284 -137.265371  -87.309580
# 2           53        1             1 -122.907856   29.555946    7.045259
# 3           41        1             1  -93.477237   27.385213    4.154832
# 4           74        0             1  193.253819 -117.221728  317.958726
# 5           30        1             1   -0.127585  -23.401831    8.413160
# 6           45        1             1    2.121237  -37.033577  -84.706789
# 7           43        1             1 -107.714062   24.984458    4.977817
# 8           57        1             1    3.661394  -23.182146   12.659465
# 9           85        0             0  -87.836866   19.792978    1.174759
# 10           7        0             0   88.886433  -69.889587    5.299467
# 11          26        1             1   38.696688  -89.093317  -58.188998
# ...

# %%
import matplotlib.pyplot as plt 
from sklearn.metrics import confusion_matrix
#
y_test = data['Peptide']
y_true = data['Peptide']
# Get the predictions
#
y_pred = data['Peptide_pred']
#
# Calculate the confusion matrix
#
conf_matrix = confusion_matrix(y_true=y_test, y_pred=y_pred)
#
# Print the confusion matrix using Matplotlib
#
fig, ax = plt.subplots(figsize=(7.5, 7.5))
ax.matshow(conf_matrix, cmap=plt.cm.Blues, alpha=0.3)
for i in range(conf_matrix.shape[0]):
    for j in range(conf_matrix.shape[1]):
        ax.text(x=j, y=i,s=conf_matrix[i, j], va='center', ha='center', size='xx-large')
 
plt.xlabel('Predictions', fontsize=18)
plt.ylabel('Actuals', fontsize=18)
plt.title('logistic_regression-mean_PCA', fontsize=18)
plt.show()

# %%
data = pd.read_csv('Data/logistic_regression/logistic_regression-variants_processed_knn.csv', low_memory=False)
data
# Out:
#     Unnamed: 0  Peptide  Peptide_pred
# 0            2        0             0  \
# 1           13        0             0
# 2           53        1             1
# 3           41        1             1
# 4           74        0             0
# 5           30        1             1
# 6           45        1             1
# 7           43        1             1
# 8           57        1             1
# 9           85        0             0
# 10           7        0             0
# 11          26        1             1
# 12          33        1             1
# 13          62        0             0
# 14           8        0             0
# 15          16        0             0
# 16          24        1             1
# 17          56        1             1
#
#     K.[304.207]GARLIPEMDQIFTEVEMTTLE(K,304.207).V
# 0                                        3.391896  \
# 1                                        2.074571
# 2                                        2.926539
# ...

# %%
import matplotlib.pyplot as plt 
from sklearn.metrics import confusion_matrix
#
y_test = data['Peptide']
y_true = data['Peptide']
# Get the predictions
#
y_pred = data['Peptide_pred']
#
# Calculate the confusion matrix
#
conf_matrix = confusion_matrix(y_true=y_test, y_pred=y_pred)
#
# Print the confusion matrix using Matplotlib
#
fig, ax = plt.subplots(figsize=(7.5, 7.5))
ax.matshow(conf_matrix, cmap=plt.cm.Blues, alpha=0.3)
for i in range(conf_matrix.shape[0]):
    for j in range(conf_matrix.shape[1]):
        ax.text(x=j, y=i,s=conf_matrix[i, j], va='center', ha='center', size='xx-large')
 
plt.xlabel('Predictions', fontsize=18)
plt.ylabel('Actuals', fontsize=18)
plt.title('logistic_regression-variants_processed_knn', fontsize=18)
plt.show()

# %%
data = pd.read_csv('Data/logistic_regression/logistic_regression-variants_processed_mean.csv', low_memory=False)
data
# Out:
#     Unnamed: 0  Peptide  Peptide_pred
# 0            2        0             0  \
# 1           13        0             0
# 2           53        1             1
# 3           41        1             1
# 4           74        0             0
# 5           30        1             1
# 6           45        1             1
# 7           43        1             1
# 8           57        1             1
# 9           85        0             0
# 10           7        0             0
# 11          26        1             1
# 12          33        1             1
# 13          62        0             0
# 14           8        0             0
# 15          16        0             0
# 16          24        1             1
# 17          56        1             1
#
#     K.[304.207]GARLIPEMDQIFTEVEMTTLE(K,304.207).V
# 0                                        3.391896  \
# 1                                        2.713450
# 2                                        2.926539
# ...

# %%
import matplotlib.pyplot as plt 
from sklearn.metrics import confusion_matrix
#
y_test = data['Peptide']
y_true = data['Peptide']
# Get the predictions
#
y_pred = data['Peptide_pred']
#
# Calculate the confusion matrix
#
conf_matrix = confusion_matrix(y_true=y_test, y_pred=y_pred)
#
# Print the confusion matrix using Matplotlib
#
fig, ax = plt.subplots(figsize=(7.5, 7.5))
ax.matshow(conf_matrix, cmap=plt.cm.Blues, alpha=0.3)
for i in range(conf_matrix.shape[0]):
    for j in range(conf_matrix.shape[1]):
        ax.text(x=j, y=i,s=conf_matrix[i, j], va='center', ha='center', size='xx-large')
 
plt.xlabel('Predictions', fontsize=18)
plt.ylabel('Actuals', fontsize=18)
plt.title('logistic_regression-variants_processed_mean', fontsize=18)
plt.show()
