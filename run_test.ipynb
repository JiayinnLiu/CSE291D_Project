# %%
# !python3 random_forest.py
# Out:
# Data set: selected_features_knn
# f1 score:  0.9539181286549707
# precision:  0.9349999999999999
# recall:  0.9800000000000001
# top_features:  [('K.[304.207](S,143.085)LHTLFGD(K,304.207).L', 0.03746668249739672), ('R.[304.207]YYWGGQ(Y,21.988)TWDMA(K,304.207).H', 0.020137309775491136), ('K.[304.207]SLHTLFGD(K,330.707)L(C,57.021)TVA.T', 0.019953824926102877), ('K.[304.207]T(C,57.021)VADESAEN(C,-24.339)D(K,304.207)SLHTLFGD(K,304.207).L', 0.018788054784370976), ('E.[304.207](T,-36.719)TLE(K,304.207)(C,57.021)(C,57.021)AAADPHE(C,57.021)YA(K,304.207).V', 0.017451532129696166), ('K.[304.207]VGPEAD(K,304.207)YR.L', 0.01730995051923449), ('K.[304.207]SPDVI(N,-3.949)GSPISQ(K,304.207).I', 0.016921994994756016), ('S.[304.207](Q,41.283)IFHSPDLAIR.D', 0.015314436851958501), ('N.[295.084]GQPENNY(K,304.207).T', 0.014265078700705109), ('R.[304.207]IFFHLNAVA(L,20.86)GD.G', 0.01382953698202113)]
#
# Optimization terminated successfully.
#          Current function value: 0.299212
# ...
